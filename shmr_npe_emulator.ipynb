# %% [markdown]
# ## Stellar-mass emulator with a conditional density estimator (HaloFlow-style)
#
# Trained on the **z=0 snapshot only** (snap 90) of the CAMELS SB35 catalogs. Features are
# the halo mass, the 4 `t_form` percentiles, and the 35 cosmo/astro parameters.
#
# Instead of predicting a single number, we learn the full distribution
# `p(log M★ | features)` with a Mixture Density Network (a small NN whose output is a
# mixture of Gaussians, trained on the negative log-likelihood). This is the same idea
# HaloFlow uses with a normalizing flow, and it directly answers the scatter-quality
# question: does the emulator reproduce the real scatter, or regress to the mean?
#
# We evaluate on **held-out boxes** and report both the point R² (from the posterior mean)
# and the **68% coverage** (does the 16–84% band contain the truth ~68% of the time?).
#
# An optional cell at the end shows how to do the same thing with `sbi` (the package
# HaloFlow uses) if you prefer a normalizing flow.

# %%
import glob, os
import numpy as np
import pandas as pd
import h5py
import matplotlib.pyplot as plt
from tqdm import tqdm

import torch
import torch.nn as nn
from sklearn.ensemble import HistGradientBoostingRegressor
from sklearn.metrics import r2_score, mean_squared_error

OUT_DIR    = '/home/jovyan/home/shmr_merger/camels_mass_history'
PARAM_FILE = ('/home/jovyan/Sims/IllustrisTNG/L50n512/SB35/'
              'CosmoAstroSeed_IllustrisTNG_L50n512_SB35.txt')
PERCENTS   = [10, 25, 50, 90]
Z0_SNAP    = 90                              # z=0 snapshot in the CAMELS catalogs

with open(PARAM_FILE) as fh:
    PARAM_KEYS = [c for c in fh.readline().lstrip('#').split()[1:] if c.lower() != 'seed']
print(f'{len(PARAM_KEYS)} parameter features')

TFORM_COLS = [f't_form_{p}' for p in PERCENTS]

torch.manual_seed(0)
np.random.seed(0)
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print('device:', device)
# Out:
# 35 parameter features
# device: cpu

# %% [markdown]
# ### 1. Build the z=0 table (snapshot 90 only)
#
# Read just the z=0 snapshot from each box: the selected halos, their `t_form`s, stellar
# mass, and the box's cosmo/astro parameters.

# %%
def build_table(files, z0_snap=Z0_SNAP):
    blocks = []
    for bi, fn in enumerate(tqdm(files)):
        with h5py.File(fn, 'r') as f:
            try:
                par = {k: float(f.attrs[k]) for k in PARAM_KEYS}
            except KeyError:
                continue                                    # header missing a param

            g0 = f[f'snap_{z0_snap:03d}']
            n  = int(g0.attrs['n_halos'])
            if n == 0:
                continue

            df = pd.DataFrame({c: g0[c][:] for c in
                               ['M200c_snap', 'Mstar'] + TFORM_COLS})
            for k, v in par.items():
                df[k] = v
            df['box'] = bi
            blocks.append(df)

    out = pd.concat(blocks, ignore_index=True)
    out['logM200c'] = np.log10(out['M200c_snap'])
    out['logMstar'] = np.log10(out['Mstar'])
    return out


files = sorted(glob.glob(f'{OUT_DIR}/*_dm_mass_history.hdf5'))
print(f'{len(files)} box files')
df = build_table(files)
print('raw rows:', len(df))
# Out:
# 1023 box files
# 100%|██████████| 1023/1023 [00:10<00:00, 93.28it/s]
# raw rows: 4203087
# /srv/conda/envs/notebook/lib/python3.9/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
FEATURES = ['logM200c'] + TFORM_COLS + PARAM_KEYS

# keep halos with stars, a real mass, valid t_forms
df = df[(df['Mstar'] > 0) & (df['M200c_snap'] > 0)].copy()
df = df.dropna(subset=FEATURES + ['logMstar'])

print(f'{len(df):,} rows from {df["box"].nunique()} boxes')
df[FEATURES + ['logMstar']].describe().T[['mean', 'std', 'min', 'max']]
# Out:
# 4,052,699 rows from 1023 boxes
#                                           mean          std         min  \
# logM200c                             11.511829     0.480484   11.000000
# t_form_10                             1.883416     1.095127    0.173186
# t_form_25                             3.042407     1.654404    0.232072
# t_form_50                             5.012436     2.515035    0.320736
# t_form_90                             9.402587     3.202435    0.349264
# Omega0                                0.358048     0.100076    0.100100
# sigma8                                0.798667     0.115084    0.600080
# WindEnergyIn1e51erg                   4.698458     3.603560    0.901210
# RadioFeedbackFactor                   1.353691     1.023597    0.250210
# VariableWindVelFactor                 7.905817     3.135387    3.701300
# RadioFeedbackReiorientationFactor    21.655599     8.528840   10.007000
# OmegaBaryon                           0.048504     0.011535    0.029019
# HubbleParam                           0.660344     0.115578    0.471110
# n_s                                   0.976933     0.114200    0.762490
# MaxSfrTimescale                       2.441085     0.965557    1.136100
# FactorForSofterEQS                    0.363590     0.222436    0.100010
# IMFslope                             -2.299244     0.290468   -2.799300
# SNII_MinMass_Msun                     8.036166     2.304281    4.006100
# ThermalWindFraction                   0.134238     0.101785    0.025043
# VariableWindSpecMomentum           1994.100364  1153.247982    3.631600
# WindFreeTravelDensFac                 0.111949     0.127193    0.005016
# MinWindVel                          345.867907   115.849442  150.280000
# WindEnergyReductionFactor             0.338062     0.256471    0.062636
# WindEnergyReductionMetallicity        0.002696     0.002037    0.000501
# WindEnergyReductionExponent           2.002429     0.577909    1.000200
# WindDumpFactor                        0.599652     0.231164    0.200040
# SeedBlackHoleMass                     0.000099     0.000063    0.000025
# BlackHoleAccretionFactor              1.352549     1.024549    0.250020
# BlackHoleEddingtonFactor              2.152808     2.502095    0.100160
# BlackHoleFeedbackFactor               0.134754     0.101998    0.025015
# BlackHoleRadiativeEfficiency          0.269097     0.203765    0.050007
# QuasarThreshold                       0.008985     0.014180    0.000063
# QuasarThresholdPower                  2.012456     1.151387    0.002932
# UVBH0beta                             3.113769     2.580756    0.464440
# UVBH0Deltaz                          -2.502044     1.444184   -4.997700
# UVBHepbeta                            1.346025     1.022065    0.250010
# UVBHepDeltaz                         -0.499693     0.287631   -0.999750
# SNIa_Rate_Norm                        0.001301     0.000259    0.000851
# SNIa_Rate_DTD_power                   1.120182     0.138545    0.880460
# SofteningComovingType01               2.162319     0.853239    1.000800
# logMstar                              8.956009     0.982760    6.019100
#
#                                            max
# logM200c                             15.315791
# t_form_10                            24.649198
# t_form_25                            24.649198
# t_form_50                            24.754040
# t_form_90                            25.577745
# Omega0                                0.499630
# sigma8                                0.999830
# WindEnergyIn1e51erg                  14.399000
# RadioFeedbackFactor                   3.995700
# VariableWindVelFactor                14.789000
# RadioFeedbackReiorientationFactor    39.947000
# OmegaBaryon                           0.068995
# HubbleParam                           0.870760
# n_s                                   1.162000
# MaxSfrTimescale                       4.535600
# FactorForSofterEQS                    0.899030
# IMFslope                             -1.800900
# SNII_MinMass_Msun                    11.999000
# ThermalWindFraction                   0.399680
# VariableWindSpecMomentum           3998.800000
# WindFreeTravelDensFac                 0.499890
# MinWindVel                          549.660000
# WindEnergyReductionFactor             0.999670
# WindEnergyReductionMetallicity        0.007981
# WindEnergyReductionExponent           2.998500
# WindDumpFactor                        0.999680
# SeedBlackHoleMass                     0.000253
# BlackHoleAccretionFactor              3.999200
# BlackHoleEddingtonFactor              9.996200
# BlackHoleFeedbackFactor               0.399480
# BlackHoleRadiativeEfficiency          0.797900
# QuasarThreshold                       0.062845
# QuasarThresholdPower                  3.999400
# UVBH0beta                             9.985700
# UVBH0Deltaz                          -0.002218
# UVBHepbeta                            3.995600
# UVBHepDeltaz                         -0.000504
# SNIa_Rate_Norm                        0.001749
# SNIa_Rate_DTD_power                   1.359600
# SofteningComovingType01               3.995400
# logMstar                             13.303416

# %% [markdown]
# ### 2. Split by box (generalization to unseen parameter sets)

# %%
rng = np.random.default_rng(0)
all_boxes  = df['box'].unique()
test_boxes = rng.choice(all_boxes, size=max(1, int(0.15 * len(all_boxes))), replace=False)
is_test    = df['box'].isin(test_boxes).to_numpy()

y = df['logMstar'].to_numpy(np.float32)
print(f'train {(~is_test).sum():,} rows / {len(all_boxes)-len(test_boxes)} boxes   '
      f'test {is_test.sum():,} rows / {len(test_boxes)} boxes')
# Out:
# train 3,429,038 rows / 870 boxes   test 623,661 rows / 153 boxes

# %% [markdown]
# ### 3. HGB baseline (point estimate)
#
# Your existing gradient-boosting emulator on the z=0 features, as the point-prediction
# reference the density model is compared against.

# %%
X_all = df[FEATURES].to_numpy(np.float32)
hgb = HistGradientBoostingRegressor(
    max_iter=600, learning_rate=0.05, max_leaf_nodes=63,
    l2_regularization=1.0, early_stopping=True, n_iter_no_change=25,
    random_state=0)
hgb.fit(X_all[~is_test], y[~is_test])
p = hgb.predict(X_all[is_test])
r2_hgb   = r2_score(y[is_test], p)
rmse_hgb = np.sqrt(mean_squared_error(y[is_test], p))
print(f'HGB (z=0)   R2={r2_hgb:.4f}  RMSE={rmse_hgb:.4f} dex')
# Out:
# HGB (z=0)   R2=0.8776  RMSE=0.3451 dex

# %% [markdown]
# ### 4. Conditional density estimator (Mixture Density Network)
#
# A small MLP maps the features to the parameters of a `K`-component Gaussian mixture over
# `log M★`. Trained on the negative log-likelihood, it learns the full conditional
# distribution — the posterior mean gives the point prediction, and the spread gives the
# scatter. Features and target are standardized (flows/MDNs train far better on ~N(0,1)).

# %%
X = df[FEATURES].to_numpy(np.float32)

# standardize using TRAIN statistics only
xm, xs = X[~is_test].mean(0), X[~is_test].std(0) + 1e-8
ym, ys = y[~is_test].mean(),  y[~is_test].std() + 1e-8
Xn = (X - xm) / xs
yn = ((y - ym) / ys).reshape(-1, 1)

Xtr = torch.tensor(Xn[~is_test], device=device)
ytr = torch.tensor(yn[~is_test], device=device)
Xte = torch.tensor(Xn[is_test],  device=device)
yte = torch.tensor(yn[is_test],  device=device)


class MDN(nn.Module):
    def __init__(self, d_in, n_comp=5, hidden=256):
        super().__init__()
        self.body = nn.Sequential(
            nn.Linear(d_in, hidden), nn.ReLU(),
            nn.Linear(hidden, hidden), nn.ReLU(),
            nn.Linear(hidden, hidden), nn.ReLU())
        self.pi     = nn.Linear(hidden, n_comp)
        self.mu     = nn.Linear(hidden, n_comp)
        self.logsig = nn.Linear(hidden, n_comp)

    def forward(self, x):
        h = self.body(x)
        return self.pi(h), self.mu(h), self.logsig(h).clamp(-7, 7)


def mdn_nll(pi, mu, logsig, target):
    logpi = torch.log_softmax(pi, dim=1)
    comp  = -0.5 * ((target - mu) / torch.exp(logsig))**2 - logsig - 0.5*np.log(2*np.pi)
    return -torch.logsumexp(logpi + comp, dim=1).mean()


net = MDN(X.shape[1], n_comp=5, hidden=256).to(device)
opt = torch.optim.Adam(net.parameters(), lr=1e-3, weight_decay=1e-5)
sched = torch.optim.lr_scheduler.ReduceLROnPlateau(opt, factor=0.5, patience=15)

N, bs = Xtr.shape[0], 4096
best, best_state, bad = np.inf, None, 0
for epoch in range(300):
    net.train(); perm = torch.randperm(N, device=device)
    for i in range(0, N, bs):
        idx = perm[i:i+bs]
        opt.zero_grad()
        loss = mdn_nll(*net(Xtr[idx]), ytr[idx])
        loss.backward(); opt.step()
    net.eval()
    with torch.no_grad():
        vnll = mdn_nll(*net(Xte), yte).item()
    sched.step(vnll)
    if vnll < best - 1e-4:
        best, best_state, bad = vnll, {k: v.clone() for k, v in net.state_dict().items()}, 0
    else:
        bad += 1
    if epoch % 20 == 0 or bad == 0:
        print(f'epoch {epoch:3d}  val NLL={vnll:.4f}  (best {best:.4f})')
    if bad >= 30:
        print(f'early stop at epoch {epoch}'); break
net.load_state_dict(best_state)
# Out:
# epoch   0  val NLL=0.5657  (best 0.5657)
# epoch   1  val NLL=0.5398  (best 0.5398)
# epoch   8  val NLL=0.5359  (best 0.5359)
# epoch   9  val NLL=0.5346  (best 0.5346)
# epoch  11  val NLL=0.5075  (best 0.5075)
# epoch  13  val NLL=0.4735  (best 0.4735)
# epoch  20  val NLL=0.4678  (best 0.4678)
# epoch  21  val NLL=0.4551  (best 0.4551)
# epoch  22  val NLL=0.4504  (best 0.4504)
# epoch  40  val NLL=0.5588  (best 0.4504)
# early stop at epoch 52
# <All keys matched successfully>

# %% [markdown]
# ### 5. Posterior summaries: mean (→ R²), spread, and quantiles
#
# For a Gaussian mixture the moments are closed-form, so the posterior mean and std are
# exact (no sampling). We sample only for the 16/84 quantiles used in the coverage test.

# %%
@torch.no_grad()
def mdn_moments(x):
    """Posterior mean and std in PHYSICAL (un-standardized) log M* units."""
    pi, mu, logsig = net(x)
    w   = torch.softmax(pi, dim=1)
    sig = torch.exp(logsig)
    mean = (w * mu).sum(1)
    var  = (w * (sig**2 + mu**2)).sum(1) - mean**2
    return (mean.cpu().numpy()*ys + ym), (np.sqrt(var.cpu().numpy())*ys)


@torch.no_grad()
def mdn_sample(x, n=400):
    """Draw n samples of log M* (physical units) for each row of x."""
    pi, mu, logsig = net(x)
    w = torch.softmax(pi, dim=1)
    comp = torch.multinomial(w, n, replacement=True)              # (B, n)
    mu_s  = torch.gather(mu,             1, comp)
    sig_s = torch.gather(torch.exp(logsig), 1, comp)
    s = mu_s + sig_s * torch.randn_like(mu_s)
    return s.cpu().numpy() * ys + ym


post_mean, post_std = mdn_moments(Xte)
ytrue = y[is_test]

r2_mdn   = r2_score(ytrue, post_mean)
rmse_mdn = np.sqrt(mean_squared_error(ytrue, post_mean))
print(f'MDN posterior mean   R2={r2_mdn:.4f}  RMSE={rmse_mdn:.4f} dex')
print(f'(HGB baseline        R2={r2_hgb:.4f}  RMSE={rmse_hgb:.4f} dex)')

# coverage: does the 16-84% band contain the truth ~68% of the time?
samp = mdn_sample(Xte, n=400)
lo, hi = np.quantile(samp, [0.16, 0.84], axis=1)
cover = np.mean((ytrue >= lo) & (ytrue <= hi))
print(f'\n68% coverage = {cover:.3f}   (calibrated ≈ 0.68)')
print(f'median 16-84 width = {np.median(hi-lo):.3f} dex')
# Out:
# MDN posterior mean   R2=0.9189  RMSE=0.2809 dex
# (HGB baseline        R2=0.8776  RMSE=0.3451 dex)
#
# 68% coverage = 0.484   (calibrated ≈ 0.68)
# median 16-84 width = 0.322 dex

# %% [markdown]
# ### 6. Is the scatter right — and is it calibrated at every halo mass?
#
# Left: the predicted posterior spread vs the actual residual scatter, per mass bin (they
# should track each other if the model is honest). Right: coverage per mass bin (should sit
# on the dashed 0.68 line everywhere, not just on average).

# %%
logM_te = df.loc[is_test, 'logM200c'].to_numpy()
resid   = post_mean - ytrue
in_band = (ytrue >= lo) & (ytrue <= hi)

bins    = np.arange(11.0, 14.25, 0.25)
centers = 0.5 * (bins[:-1] + bins[1:])
std_resid, std_pred, cov_bin, N = [], [], [], []
for a, b in zip(bins[:-1], bins[1:]):
    m = (logM_te >= a) & (logM_te < b)
    if m.sum() < 30:
        std_resid.append(np.nan); std_pred.append(np.nan); cov_bin.append(np.nan)
    else:
        std_resid.append(resid[m].std())
        std_pred.append(post_std[m].mean())
        cov_bin.append(in_band[m].mean())
    N.append(m.sum())
ok = np.array(N) >= 30

fig, ax = plt.subplots(1, 2, figsize=(13, 5))
ax[0].plot(centers[ok], np.array(std_resid)[ok], 'k-o', label=r'$\sigma$(residual)')
ax[0].plot(centers[ok], np.array(std_pred)[ok],  'C3--s', label=r'mean predicted $\sigma$')
ax[0].set_xlabel(r'$\log_{10}(M_{200c}/M_\odot)$'); ax[0].set_ylabel('scatter [dex]')
ax[0].set_title('Predicted spread vs actual residual scatter'); ax[0].legend(); ax[0].grid(alpha=0.3)

ax[1].plot(centers[ok], np.array(cov_bin)[ok], 'C0-o')
ax[1].axhline(0.68, color='k', ls='--', lw=1, label='target 0.68')
ax[1].set_xlabel(r'$\log_{10}(M_{200c}/M_\odot)$'); ax[1].set_ylabel('68% coverage')
ax[1].set_ylim(0, 1); ax[1].set_title('Calibration by halo mass'); ax[1].legend(); ax[1].grid(alpha=0.3)
plt.tight_layout(); plt.show()

# %% [markdown]
# ### 7. SHMR with a real scatter band
#
# Vary halo mass, hold the assembly + astro parameters at their medians, and draw the
# posterior median plus the 16–84% band — the band the point emulator could never give you.

# %%
med = {f: float(df[f].median()) for f in FEATURES}
logMs = np.linspace(df['logM200c'].min(), df['logM200c'].quantile(0.999), 60)

rows = np.tile([med[f] for f in FEATURES], (len(logMs), 1)).astype(np.float32)
rows[:, FEATURES.index('logM200c')] = logMs
Xq = torch.tensor((rows - xm) / xs, device=device)

samp = mdn_sample(Xq, n=2000)
q16, q50, q84 = np.quantile(samp, [0.16, 0.50, 0.84], axis=1)

fig, ax = plt.subplots(figsize=(7.5, 6))
h = ax.hist2d(df['logM200c'], df['logMstar'], bins=120, cmin=1, cmap='Greys')
ax.plot(logMs, q50, 'C3-', lw=2.5, label='posterior median')
ax.fill_between(logMs, q16, q84, color='C3', alpha=0.25, label='16–84% (predicted scatter)')
ax.set_xlabel(r'$\log_{10}(M_{200c}/M_\odot)$'); ax.set_ylabel(r'$\log_{10}(M_\star/M_\odot)$')
ax.set_title('SHMR with predicted scatter (median params)'); ax.legend()
plt.tight_layout(); plt.show()

# %% [markdown]
# ### 8. (optional) The same thing with `sbi` — a normalizing flow, like HaloFlow
#
# If you'd rather use a flow via the exact package HaloFlow uses, this trains an amortized
# NPE `q(log M★ | features)`. Set `theta` 2-D (`logM200c, logMstar`) and drop `logM200c`
# from the conditions to do the *joint* `(M_h, M_*)` inference HaloFlow does literally.

# %%
import sbi
from sbi.inference import SNPE
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[17], line 2
#       1 import sbi
# ----> 2 from sbi.inference import SNPE
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/sbi/inference/__init__.py:8
#       2 from sbi.inference.trainers.base import (
#       3     NeuralInference,  # noqa: F401
#       4     check_if_proposal_has_default_x,
#       5     infer,
#       6 )
#       7 from sbi.inference.trainers.fmpe import FMPE
# ----> 8 from sbi.inference.trainers.nle import MNLE, NLE_A
#       9 from sbi.inference.trainers.npe import NPE_A, NPE_B, NPE_C  # noqa: F401
#      10 from sbi.inference.trainers.npse import NPSE
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/sbi/inference/trainers/nle/__init__.py:1
# ----> 1 from sbi.inference.trainers.nle.mnle import MNLE  # noqa: F401
#       2 from sbi.inference.trainers.nle.nle_a import NLE_A  # noqa: F401
#       4 SNLE = SNLE_A = NLE = NLE_A
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/sbi/inference/trainers/nle/mnle.py:9
#       5 from typing import Any, Callable, Dict, Optional, Union
#       7 from torch.distributions import Distribution
# ----> 9 from sbi.inference.posteriors import MCMCPosterior, RejectionPosterior, VIPosterior
#      10 from sbi.inference.potentials import likelihood_estimator_based_potential
#      11 from sbi.inference.trainers.nle.nle_base import LikelihoodEstimator
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/sbi/inference/posteriors/__init__.py:4
#       2 from sbi.inference.posteriors.ensemble_posterior import EnsemblePosterior
#       3 from sbi.inference.posteriors.importance_posterior import ImportanceSamplingPosterior
# ----> 4 from sbi.inference.posteriors.mcmc_posterior import MCMCPosterior
#       5 from sbi.inference.posteriors.rejection_posterior import RejectionPosterior
#       6 from sbi.inference.posteriors.score_posterior import ScorePosterior
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/sbi/inference/posteriors/mcmc_posterior.py:25
#      23 from sbi.inference.potentials.base_potential import BasePotential
#      24 from sbi.neural_nets.estimators.shape_handling import reshape_to_batch_event
# ---> 25 from sbi.samplers.mcmc import (
#      26     IterateParameters,
#      27     PyMCSampler,
#      28     SliceSamplerSerial,
#      29     SliceSamplerVectorized,
#      30     proposal_init,
#      31     resample_given_potential_fn,
#      32     sir_init,
#      33 )
#      34 from sbi.sbi_types import Shape, TorchTransform
#      35 from sbi.utils.potentialutils import pyro_potential_wrapper, transformed_potential
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/sbi/samplers/mcmc/__init__.py:7
#       1 from sbi.samplers.mcmc.init_strategy import (
#       2     IterateParameters,
#       3     proposal_init,
#       4     resample_given_potential_fn,
#       5     sir_init,
#       6 )
# ----> 7 from sbi.samplers.mcmc.pymc_wrapper import PyMCSampler
#       8 from sbi.samplers.mcmc.slice_numpy import (
#       9     SliceSampler,
#      10     SliceSamplerSerial,
#      11     SliceSamplerVectorized,
#      12 )
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/sbi/samplers/mcmc/pymc_wrapper.py:4
#       1 from typing import Any, Callable, Optional
#       3 import numpy as np
# ----> 4 import pymc
#       5 import pytensor.tensor as pt
#       6 import torch
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/pymc/__init__.py:48
#      43     pytensor.config.gcc__cxxflags = augmented
#      46 __set_compiler_flags()
# ---> 48 from pymc import _version, gp, ode, sampling
#      49 from pymc.backends import *
#      50 from pymc.blocking import *
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/pymc/gp/__init__.py:15
#       1 #   Copyright 2024 The PyMC Developers
#       2 #
#       3 #   Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      12 #   See the License for the specific language governing permissions and
#      13 #   limitations under the License.
# ---> 15 from pymc.gp import cov, mean, util
#      16 from pymc.gp.gp import (
#      17     TP,
#      18     Latent,
#    (...)
#      23     MarginalSparse,
#      24 )
#      25 from pymc.gp.hsgp_approx import HSGP, HSGPPeriodic
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/pymc/gp/util.py:23
#      21 from pytensor.graph import ancestors
#      22 from pytensor.tensor.variable import TensorConstant
# ---> 23 from scipy.cluster.vq import kmeans
#      25 # Avoid circular dependency when importing modelcontext
#      26 from pymc.distributions.distribution import Distribution
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/scipy/cluster/__init__.py:27
#       1 """
#       2 =========================================
#       3 Clustering package (:mod:`scipy.cluster`)
#    (...)
#      23
#      24 """
#      25 __all__ = ['vq', 'hierarchy']
# ---> 27 from . import vq, hierarchy
#      29 from scipy._lib._testutils import PytestTester
#      30 test = PytestTester(__name__)
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/scipy/cluster/vq.py:70
#      68 import numpy as np
#      69 from collections import deque
# ---> 70 from scipy._lib._array_api import (
#      71     as_xparray, array_namespace, size, atleast_nd, copy, cov
#      72 )
#      73 from scipy._lib._util import check_random_state, rng_integers
#      74 from scipy.spatial.distance import cdist
#
# ImportError: cannot import name 'as_xparray' from 'scipy._lib._array_api' (/srv/conda/envs/notebook/lib/python3.9/site-packages/scipy/_lib/_array_api.py)

# %%
# pip install sbi
try:
    from sbi.inference import SNPE              # newer sbi: `from sbi.inference import NPE as SNPE`

    theta = torch.tensor(yn[~is_test])           # target = standardized log M*
    xcond = torch.tensor(Xn[~is_test])           # conditions = standardized features

    inference = SNPE(density_estimator='nsf')     # neural spline flow
    inference.append_simulations(theta, xcond)
    de = inference.train(training_batch_size=512, max_num_epochs=200)
    posterior = inference.build_posterior(de)     # amortized q(logM* | features)

    # point + coverage on a test subsample (sampling per point is slower than the MDN)
    sub = np.where(is_test)[0]
    sub = np.random.default_rng(0).choice(len(sub), size=min(3000, len(sub)), replace=False)
    Xs  = torch.tensor(Xn[is_test][sub])
    pm, c_lo, c_hi = [], [], []
    for i in range(len(Xs)):
        s = posterior.sample((300,), x=Xs[i], show_progress_bars=False).numpy().ravel()*ys + ym
        pm.append(s.mean()); q = np.quantile(s, [0.16, 0.84]); c_lo.append(q[0]); c_hi.append(q[1])
    yt = y[is_test][sub]
    print(f'sbi NPE  R2={r2_score(yt, pm):.4f}   '
          f'68% coverage={np.mean((yt>=np.array(c_lo))&(yt<=np.array(c_hi))):.3f}')
except ImportError:
    print('sbi not installed — `pip install sbi` to run this cell (the MDN above already '
          'gives you the calibrated posterior).')
# Out:
# sbi not installed — `pip install sbi` to run this cell (the MDN above already gives you the calibrated posterior).
